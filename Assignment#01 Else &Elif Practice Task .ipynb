# %% [markdown]
#   NAME:Syed Saad Hussain Teacher: Sir Faisal Roll No:178163 Batch: PY Batch (2) timing: 09:00 to 11:00PM

# %% [raw]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
Salary=int(input("enter the salary:"))
Year=int(input("enter the year:"))
Inc=(Salary*5)/100+Salary
if 5 < Year :
   print("bonus amount:",Inc)
elif 5 > Year:
   print("not eligible for inc")
else:
   print("nothing else")
# Out:
# enter the salary:30000
# enter the year:9
# bonus amount: 31500.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
Boy_age=int(input("enter the age of boy:"))
if 17 < Boy_age:
  print("Not eligible for Vote")
elif 18 > Boy_age:
  print("Eligible for Vote")
else:
  print("Nothing else go")
# Out:
# enter the age of boy:17
# Eligible for Vote

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
User_number=int(input("enter the user number:"))
if(User_number%4)==0:
  print("even number")
else:
  print("odd number")
# Out:
# enter the user number:397
# odd number

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
User_number=int(input("enter the user number:"))
if(User_number%7)==0:
  print("divisible")
else:
  print("not divisible")
# Out:
# enter the user number:7
# divisible

# %% [raw]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
User_number=int(input("enter the user number:"))
if(User_number%5)==0:
  print("Hello")
else:
  print("Bye")
# Out:
# enter the user number:33
# Bye

# %% [raw]
# 7) Write a program to display the last digit of a number.

# %%
Number = int(input("enter the number:"))
Last_digit = Number % 10
print("last digit of a number:",Last_digit)
# Out:
# enter the number:11446
# last digit of a number: 6

# %% [raw]
# Q8. Write a program to check whether the last digit of a number( entered by user ) is
# divisible by 3 or not.

# %%
Number = int(input("enter the number:"))
Last_digit = Number % 10
if Last_digit%3==0:
  print("Divisible")
else:
  print("Not Divisible")
# Out:
# enter the number:11446
# Divisible

# %% [raw]
# *9*) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
Take_a_length= int(input("lets enter the length:"))
Take_a_breadth= int(input("lets enter the breadth:"))
if Take_a_length==Take_a_breadth:
  print("Print it is Sqare")
else:
  print("Print it is breadth")
# Out:
# lets enter the length:12
# lets enter the breadth:13
# Print it is breadth

# %% [raw]
# 10) Take two int values from user and print greatest among them.

# %%
Value_num_1= int(input("let enter value one:"))
Value_num_2= int(input("let enter value two:"))
if Value_num_2<Value_num_1:
  print("Print gratest value:",Value_num_1)
elif Value_num_2>Value_num_1:
   print("Print gratest value:",Value_num_2)
else:
  print("nothing else greatest value")
# Out:
# let enter value one:88
# let enter value two:468
# Print gratest value: 468

# %% [raw]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
Quantity=int(input("enter the quantity:"))
Judge=Quantity*100
Discount=Judge-((Judge*10)/100)
if 1000<Quantity:
  print("Print total cost",Discount)
else:
  print("No discount avialable")
# Out:
# enter the quantity:1500
# Print total cost 135000.0

# %% [raw]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
Marks=int(input("enter the marks:"))
if Marks>82:
  print("A")
elif Marks>64 & Marks<70:
  print("B")
elif Marks>52 & Marks<60:
  print("C")
elif Marks>41 & Marks<50:
  print("D")
else:
  print("Fail")
# Out:
# enter the marks:83
# A

# %% [raw]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# Number of classes held
#
# Number of classes attended.
#
# And print
#
# percentage of class attended
#
# Is student is allowed to sit in exam or not.

# %%
NH=int(input("No of classes heald:"))
NA=int(input("No of classes Attended:"))
P=(NA/NH)*100
print("Percentage",P,"%")
if NA<75:
  print("Not be allowed to sit in examination")
else:
  print("Allowed to sit in examination")
# Out:
# No of classes heald:200
# No of classes Attended:150
# Percentage 75.0 %
# Allowed to sit in examination

# %% [raw]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
from re import U
User=(input("Do you have medical cause:"))
if User=="Y":
  print("you can sit now")
else:
  print("you are not allow to sit")
# Out:
# Do you have medical cause:Y
# you can sit now

# %% [raw]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
Year =int(input("enter the years:"))
if(Year%4 & Year%200!=0 & Year%400==0):
  print("It is Leap Year")
else:
  ("That is not leap Year")
# Out:
# enter the years:30
# It is Leap Year

# %% [raw]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
Age= int(input("enter the Age:"))
Gender=(input("enter the Gender:"))
Marital_Status=(input("enter the marital status:"))
if Gender=="female":
  print("female will work only urban areas")
elif Gender=="Male" and 20<Age<40:
  print("Males will work anywhere")
elif Gender=="Male" and 40<Age<60:
    print("Males will work only urban areas")
else:
  print("ERROR")
# Out:
# enter the Age:26
# enter the Gender:Male
# enter the marital status:S
# Males will work anywhere

# %% [raw]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %% [raw]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
Unit=int(input("enter the unit:"))
if 100<Unit:
  print("Amount is:", Unit*5, "rupees")
elif 200>Unit:
  print("Amount is", Unit*10, "rupees")
elif 100>Unit:
  print(Unit*0,"rupees")
else:
  ("ERROR")
# Out:
# enter the unit:97
# Amount is 970 rupees
